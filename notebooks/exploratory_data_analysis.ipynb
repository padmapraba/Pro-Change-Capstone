# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %%
# import all the datasets
gw_19 = pd.read_csv('data/globalwarming/globalwarming_2019.csv')
# climatechange_20 = pd.read_csv('data/climatechange/climatechange_2020.csv')
# climatechange_21 = pd.read_csv('data/climatechange/climatechange_2021.csv')
# climatechange_22 = pd.read_csv('data/climatechange/climatechange_2022.csv')
# datasets = [climatechange_19,climatechange_20,climatechange_21,climatechange_22]

# %%
gw_19
# Out:
#                         Datetime             Tweet Id  \
# 0      2019-01-01 23:59:01+00:00  1080252085629829120
# 1      2019-01-01 23:58:51+00:00  1080252039857287170
# 2      2019-01-01 23:58:47+00:00  1080252025684852736
# 3      2019-01-01 23:58:27+00:00  1080251941333151745
# 4      2019-01-01 23:58:13+00:00  1080251882164183041
# ...                          ...                  ...
# 36496  2019-12-31 23:19:08+00:00  1212151230601891840
# 36497  2019-12-31 23:18:45+00:00  1212151132669145088
# 36498  2019-12-31 23:18:35+00:00  1212151089665118215
# 36499  2019-12-31 23:18:06+00:00  1212150967598305280
# 36500  2019-12-31 23:17:37+00:00  1212150848752701441
#
#                                                     Text         Username  \
# 0      Great Grandpa’s thoughts on global warming \n\...       EthanFaatz
# 1      @Anthonysmdoyle @AnnaJaneSmith4 @Char_Autograp...        MaxGraham
# 2      #GlobalWarming Harms Animals 🌎\nIn the Antarct...   PhilosopherSue
# ...

# %%
# Shape and Columns of the dataset
for i in datasets: print(i.shape, i.columns)
# Out:
# (3001, 11) Index(['Datetime', 'Tweet Id', 'Text', 'Username', 'Verified Status',
#        'Follower Count', 'Location', 'Reply Counts', 'Retweet Counts',
#        'Like Count', 'Media'],
#       dtype='object')
# (3001, 11) Index(['Datetime', 'Tweet Id', 'Text', 'Username', 'Verified Status',
#        'Follower Count', 'Location', 'Reply Counts', 'Retweet Counts',
#        'Like Count', 'Media'],
#       dtype='object')
# (3600, 11) Index(['Datetime', 'Tweet Id', 'Text', 'Username', 'Verified Status',
#        'Follower Count', 'Location', 'Reply Counts', 'Retweet Counts',
#        'Like Count', 'Media'],
#       dtype='object')
# (3001, 11) Index(['Datetime', 'Tweet Id', 'Text', 'Username', 'Verified Status',
#        'Follower Count', 'Location', 'Reply Counts', 'Retweet Counts',
#        'Like Count', 'Media'],
#       dtype='object')

# %%
# What do the different variables look like?
for i in datasets: 
    print(i.nunique(axis=0)) 
    print('------')
    
# DATETIME has an issue
# Out:
# Datetime           2662
# Tweet Id           3001
# Text               3000
# Username           2618
# Verified Status       2
# Follower Count     1776
# Location           1344
# Reply Counts         37
# Retweet Counts       63
# Like Count          107
# Media               335
# dtype: int64
# ------
# Datetime           2822
# Tweet Id           3001
# Text               2999
# Username           2487
# Verified Status       2
# Follower Count     1779
# Location           1275
# Reply Counts         24
# Retweet Counts       52
# Like Count           95
# Media               600
# dtype: int64
# ------
# Datetime           284
# Tweet Id           339
# Text               338
# Username           277
# Verified Status      2
# Follower Count     246
# Location           164
# Reply Counts         9
# Retweet Counts       8
# Like Count          23
# Media               83
# dtype: int64
# ------
# Datetime           2723
# Tweet Id           3001
# Text               2985
# ...

# %%
for i in datasets:
    print(i.describe().apply(lambda s: s.apply(lambda x: format(x, 'f'))))
# Out:
#                          Tweet Id   Follower Count Reply Counts  \
# count                 3001.000000      3001.000000  3001.000000
# mean   1211770819391611904.000000     38316.349883     1.255248
# std         15822451493758.777344    650576.242324    13.144080
# min    1211743820972482560.000000         0.000000     0.000000
# 25%    1211757151703617536.000000       227.000000     0.000000
# 50%    1211770260799442944.000000       954.000000     0.000000
# 75%    1211784342550274048.000000      3408.000000     1.000000
# max    1211799115119489024.000000  25524331.000000   528.000000
#
#       Retweet Counts    Like Count
# count    3001.000000   3001.000000
# mean        3.635122     12.242253
# std        48.143520    216.338898
# min         0.000000      0.000000
# 25%         0.000000      0.000000
# 50%         0.000000      0.000000
# 75%         0.000000      2.000000
# max      1884.000000  10786.000000
# ...

# %%
climatechange_19.

# %%
## Association of dates and the number tweets

# %%
## Association of dates and reply counts

# %%
## Average number of words per tweet

# %%
## Days with highest num of tweets
