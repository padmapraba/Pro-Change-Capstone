# %%
import pandas as pd
import numpy as np
import os
import json

# %%
df = pd.read_json('data/globalWarming1.json')
df['month'] = df['date'].apply(lambda x: pd.Timestamp(x).strftime('%B'))
df['date'] = df['date'].apply(lambda x: pd.Timestamp(x).strftime('%Y-%m-%d'))

# %%
df
# Out:
#                                  _type  \
# 0       snscrape.modules.twitter.Tweet
# 1       snscrape.modules.twitter.Tweet
# 2       snscrape.modules.twitter.Tweet
# 3       snscrape.modules.twitter.Tweet
# 4       snscrape.modules.twitter.Tweet
# ...                                ...
# 128608  snscrape.modules.twitter.Tweet
# 128609  snscrape.modules.twitter.Tweet
# 128610  snscrape.modules.twitter.Tweet
# 128611  snscrape.modules.twitter.Tweet
# 128612  snscrape.modules.twitter.Tweet
#
#                                                       url        date  \
# 0       https://twitter.com/MasterofIoT/status/1101270...  2019-02-28
# 1       https://twitter.com/pmagn/status/1101270778278...  2019-02-28
# 2       https://twitter.com/PeterFHyatt/status/1101270...  2019-02-28
# 3       https://twitter.com/Tlahuizcalpanti/status/110...  2019-02-28
# 4       https://twitter.com/JJJungleJim/status/1101270...  2019-02-28
# ...

# %%
df.date.unique()
# Out:
# array(['2019-02-28', '2019-02-27', '2019-02-26', '2019-02-25',
#        '2019-02-24', '2019-02-23', '2019-02-22', '2019-02-21',
#        '2019-02-20', '2019-02-19', '2019-02-18', '2019-02-17',
#        '2019-02-16', '2019-02-15', '2019-02-14', '2019-02-13',
#        '2019-02-12', '2019-02-11', '2019-02-10', '2019-02-09',
#        '2019-02-08', '2019-02-07', '2019-02-06', '2019-02-05',
#        '2019-02-04', '2019-02-03'], dtype=object)

# %%
# Out:
#                                  _type  \
# 0       snscrape.modules.twitter.Tweet
# 1       snscrape.modules.twitter.Tweet
# 2       snscrape.modules.twitter.Tweet
# 3       snscrape.modules.twitter.Tweet
# 4       snscrape.modules.twitter.Tweet
# ...                                ...
# 128608  snscrape.modules.twitter.Tweet
# 128609  snscrape.modules.twitter.Tweet
# 128610  snscrape.modules.twitter.Tweet
# 128611  snscrape.modules.twitter.Tweet
# 128612  snscrape.modules.twitter.Tweet
#
#                                                       url        date  \
# 0       https://twitter.com/MasterofIoT/status/1101270...  2019-02-28
# 1       https://twitter.com/pmagn/status/1101270778278...  2019-02-28
# 2       https://twitter.com/PeterFHyatt/status/1101270...  2019-02-28
# 3       https://twitter.com/Tlahuizcalpanti/status/110...  2019-02-28
# 4       https://twitter.com/JJJungleJim/status/1101270...  2019-02-28
# ...

# %%
df.loc[0].at["content"]
# Out:
# '@bbcquestiontime We cannot say this is just a couple of freakish days. There is an undeniable pattern. Whilst 21c in February is nice, it’s far from normal but may become the norm. And in the long term #GlobalWarming and #climatechange could be devastating. We are already seeing that @Stevewal63'

# %%
df.loc[0].at["renderedContent"]
# Out:
# '@bbcquestiontime We cannot say this is just a couple of freakish days. There is an undeniable pattern. Whilst 21c in February is nice, it’s far from normal but may become the norm. And in the long term #GlobalWarming and #climatechange could be devastating. We are already seeing that @Stevewal63'

# %%
# subset tweets with more than 100 likes
tweets_with_high_int = df.loc[df['likeCount'] > 100]
tweets_with_high_int = tweets_with_high_int.reset_index()
tweets_with_high_int
# Out:
#       index                           _type  \
# 0        64  snscrape.modules.twitter.Tweet
# 1       325  snscrape.modules.twitter.Tweet
# 2       419  snscrape.modules.twitter.Tweet
# 3       539  snscrape.modules.twitter.Tweet
# 4       570  snscrape.modules.twitter.Tweet
# ..      ...                             ...
# 681  127613  snscrape.modules.twitter.Tweet
# 682  127813  snscrape.modules.twitter.Tweet
# 683  127842  snscrape.modules.twitter.Tweet
# 684  128316  snscrape.modules.twitter.Tweet
# 685  128411  snscrape.modules.twitter.Tweet
#
#                                                    url  \
# 0    https://twitter.com/doingthe116/status/1101265...
# 1    https://twitter.com/SenFeinstein/status/110124...
# 2    https://twitter.com/lukasbattle/status/1101236...
# 3    https://twitter.com/myserenity69/status/110122...
# 4    https://twitter.com/Rogan_OConnor/status/11012...
# ..                                                 ...
# ...

# %%
# random sample
tweets_with_high_int.loc[333].at["content"]
# Out:
# '.@Melissa4Durack, can you please take this opportunity to list your achievements to date?\n\n(i’m especially interested in actions you’ve taken to mitigate australia’s contribution to global warming.) https://t.co/XJnnFiNrQr'

# %%
# get date without timestamp
df['Date'] = df['date'].apply(lambda x: "%d/%d/%d" % (x.day,x.month,x.year))
df
# Out:
#                                  _type  \
# 0       snscrape.modules.twitter.Tweet
# 1       snscrape.modules.twitter.Tweet
# 2       snscrape.modules.twitter.Tweet
# 3       snscrape.modules.twitter.Tweet
# 4       snscrape.modules.twitter.Tweet
# ...                                ...
# 128608  snscrape.modules.twitter.Tweet
# 128609  snscrape.modules.twitter.Tweet
# 128610  snscrape.modules.twitter.Tweet
# 128611  snscrape.modules.twitter.Tweet
# 128612  snscrape.modules.twitter.Tweet
#
#                                                       url  \
# 0       https://twitter.com/MasterofIoT/status/1101270...
# 1       https://twitter.com/pmagn/status/1101270778278...
# 2       https://twitter.com/PeterFHyatt/status/1101270...
# 3       https://twitter.com/Tlahuizcalpanti/status/110...
# 4       https://twitter.com/JJJungleJim/status/1101270...
# ...                                                   ...
# 128608  https://twitter.com/MickGreenhough/status/1091...
# ...

# %%
df.groupby(['Date']).size()
# Out:
# Date
# 10/2/2019    5793
# 11/2/2019    9033
# 12/2/2019    6258
# 13/2/2019    5863
# 14/2/2019    4153
# 15/2/2019    4453
# 16/2/2019    3514
# 17/2/2019    2896
# 18/2/2019    3361
# 19/2/2019    4122
# 20/2/2019    3633
# 21/2/2019    5258
# 22/2/2019    5179
# 23/2/2019    4861
# 24/2/2019    4520
# 25/2/2019    6727
# 26/2/2019    8444
# 27/2/2019    5926
# 28/2/2019    3830
# 3/2/2019     2913
# 4/2/2019     4114
# 5/2/2019     5012
# 6/2/2019     5139
# 7/2/2019     5894
# 8/2/2019     4535
# 9/2/2019     3182
# dtype: int64

# %%
tweets_with_high_int['Date'] = tweets_with_high_int['date'].apply(lambda x: "%d/%d/%d" % (x.day,x.month,x.year))

# %%
tweets_with_high_int.groupby(['Date']).size()
# Out:
# Date
# 10/2/2019    40
# 11/2/2019    46
# 12/2/2019    30
# 13/2/2019    37
# 14/2/2019    27
# 15/2/2019    23
# 16/2/2019    14
# 17/2/2019    13
# 18/2/2019    23
# 19/2/2019    24
# 20/2/2019    12
# 21/2/2019    21
# 22/2/2019    26
# 23/2/2019    30
# 24/2/2019    33
# 25/2/2019    48
# 26/2/2019    49
# 27/2/2019    25
# 28/2/2019    16
# 3/2/2019     15
# 4/2/2019     25
# 5/2/2019     26
# 6/2/2019     22
# 7/2/2019     28
# 8/2/2019     16
# 9/2/2019     17
# dtype: int64

# %%
mar_2122 = pd.read_json('data/globalWarming20210302-20220301.json')
mar_2122
# Out:
#                                  _type  \
# 0       snscrape.modules.twitter.Tweet
# 1       snscrape.modules.twitter.Tweet
# 2       snscrape.modules.twitter.Tweet
# 3       snscrape.modules.twitter.Tweet
# 4       snscrape.modules.twitter.Tweet
# ...                                ...
# 881475  snscrape.modules.twitter.Tweet
# 881476  snscrape.modules.twitter.Tweet
# 881477  snscrape.modules.twitter.Tweet
# 881478  snscrape.modules.twitter.Tweet
# 881479  snscrape.modules.twitter.Tweet
#
#                                                       url  \
# 0       https://twitter.com/frank3davies/status/149844...
# 1       https://twitter.com/DebbieLavigne3/status/1498...
# 2       https://twitter.com/markbbean/status/149844782...
# 3       https://twitter.com/ECOTerminator/status/14984...
# 4       https://twitter.com/OWStarr/status/14984477509...
# ...                                                   ...
# 881475  https://twitter.com/ChrisDu76268095/status/136...
# ...

# %%
mar_2122_high = mar_2122.loc[mar_2122['likeCount'] > 100]
mar_2122_high
# Out:
#                                  _type  \
# 205     snscrape.modules.twitter.Tweet
# 207     snscrape.modules.twitter.Tweet
# 224     snscrape.modules.twitter.Tweet
# 270     snscrape.modules.twitter.Tweet
# 276     snscrape.modules.twitter.Tweet
# ...                                ...
# 880840  snscrape.modules.twitter.Tweet
# 880949  snscrape.modules.twitter.Tweet
# 880992  snscrape.modules.twitter.Tweet
# 881011  snscrape.modules.twitter.Tweet
# 881072  snscrape.modules.twitter.Tweet
#
#                                                       url  \
# 205     https://twitter.com/bitcoinpanda69/status/1498...
# 207     https://twitter.com/FOPTonyReed/status/1498432...
# 224     https://twitter.com/TheUSASingers/status/14984...
# 270     https://twitter.com/Lukewearechange/status/149...
# 276     https://twitter.com/feedmemorris/status/149842...
# ...                                                   ...
# 880840  https://twitter.com/ClimateWarrior7/status/136...
# ...

# %%
mar_2122['Week/Year'] = mar_2122['date'].apply(lambda x: "%d/%d" % (x.week,x.year))

# %%
mar_2122.groupby(['Week/Year']).size()
# Out:
# Week/Year
# 1/2022     17336
# 10/2021    10676
# 11/2021    10639
# 12/2021    11403
# 13/2021    11270
# 14/2021    12542
# 15/2021    11493
# 16/2021    18620
# 17/2021    12135
# 18/2021    12673
# 19/2021    11332
# 2/2022     17422
# 20/2021    13389
# 21/2021    12146
# 22/2021    13661
# 23/2021    15469
# 24/2021    13670
# 25/2021    15466
# 26/2021    27011
# 27/2021    18044
# 28/2021    22165
# 29/2021    20282
# 3/2022     16754
# 30/2021    17286
# 31/2021    17114
# 32/2021    34420
# 33/2021    17113
# 34/2021    15865
# 35/2021    19923
# 36/2021    15228
# 37/2021    16111
# 38/2021    16433
# 39/2021    15107
# 4/2022     16798
# 40/2021    16235
# 41/2021    17228
# 42/2021    17736
# 43/2021    23252
# 44/2021    32109
# 45/2021    24812
# 46/2021    16739
# 47/2021    15786
# 48/2021    16422
# 49/2021    18211
# 5/2022     16416
# 50/2021    22085
# 51/2021    16348
# 52/2021    15503
# 52/2022     5920
# 6/2022     14837
# 7/2022     14592
# 8/2022     16511
# ...

# %%
sample = mar_2122_high.sample()
sample = sample.reset_index()
sample

# %%
sample.loc[0].at["content"]

# %%
mar_2122 = pd.read_json('data/globalWarming20210302-20220301.json')
mar_2122
